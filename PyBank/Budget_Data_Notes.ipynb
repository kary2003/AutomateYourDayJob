# %%
import csv
with open('Budget_Data.csv', newline='') as f:
    budget = csv.reader(f)
    for row in budget:
        print(row[1])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-0321c5932834> in <module>
#       1 import csv
# ----> 2 with open('Budget_Data.csv', newline='') as f:
#       3     budget = csv.reader(f)
#       4     for row in budget:
#       5         print(row[1])
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Budget_Data.csv'

# %%
import csv
with open('Budget_Data.csv', newline='', encoding='utf-8') as csvfile:
    month = csv.reader(csvfile)
    for row in month:
        print(row)

# %%
from pathlib import Path
print(Path.cwd())

# %%
Path = ("Budget_Data.csv")

import csv
with open('Budget_Data.csv', newline='') as f:
    budget = csv.reader(f)
    for row in budget:
        print(row[1])

# %%
with open(Path, 'r' ) as file:
    text = file.read()
    for text in file:
        print(text)
